# %%
import requests
page = requests.get('https://store.steampowered.com/app/1245620/ELDEN_RING/')

# %%
page
# status 200 successfully
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup
data = BeautifulSoup(page.content,'html.parser')

# %%
print(data)
# Out:
# <!DOCTYPE html>
#
# <html class="responsive" lang="en">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <meta content="#171a21" name="theme-color"/>
# <title>ELDEN RING on Steam</title>
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://store.akamai.steamstatic.com/public/shared/css/motiva_sans.css?v=Rc2hpzg2Ex3T&amp;l=english" rel="stylesheet" type="text/css"/>
# <link href="https://store.akamai.steamstatic.com/public/shared/css/shared_global.css?v=wy0wYJxBlt-2&amp;l=english" rel="stylesheet" type="text/css"/>
# <link href="https://store.akamai.steamstatic.com/public/shared/css/buttons.css?v=CrrkDubPqLcq&amp;l=english" rel="stylesheet" type="text/css"/>
# <link href="https://store.akamai.steamstatic.com/public/css/v6/store.css?v=kDDOuB38KTLX&amp;l=english" rel="stylesheet" type="text/css"/>
# ...

# %%
intros = data.find_all('div',class_='quote')
for intro in intros:
    x = intro.find('small')
    print(x.get_text())
# Out:
# Albert Einstein
# J.K. Rowling
# Albert Einstein
# Jane Austen
# Marilyn Monroe
# Albert Einstein
# André Gide
# Thomas A. Edison
# Eleanor Roosevelt
# Steve Martin

# %%
step_elements = data.find_all('li',class_='TYR86d zfr3Q')
for step_element in step_elements:
    step = step_element.find('p',class_='CDt4Ke zfr3Q')
    file.write('- {}\n'.format(step.text))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 4
#       2 for step_element in step_elements:
#       3     step = step_element.find('p',class_='CDt4Ke zfr3Q')
# ----> 4     file.write('- {}\n'.format(step.text))
#
# ValueError: I/O operation on closed file.

# %%
x = list(soup.children)
x
# Out:
# ['html',
# ...

# %%
x[0]
# Out:
# 'html'

# %%
with open('extracted_data1.txt','w') as file:
    file.write(content)

# %%
x[2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 x[2]
#
# IndexError: list index out of range
